# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import sys

package_root_dir = os.path.join(os.getcwd(), "..")
sys.path.append(package_root_dir)

# %%
# Load the data.
melondy_df_folder = os.path.join(package_root_dir, "data", "processed")
melondy_df = pd.read_csv(os.path.join(melondy_df_folder, "melondy.csv"))
melondy_df.head()
# Out:
#             artist                                     album  \
# 0        Integrity  Howling, for the Nightmare Shall Consume
# 1          Big Ups                        Two Parts Together
# 2        The Field                     Looping State of Mind
# 3         Mastodon                   Once More Round the Sun
# 4  Various Artists                         Dorner vs. Tookie
#
#                                                genre  \
# 0  ['hardcore punk', 'heavy metal', 'metal', 'met...
# 1                 ['indie rock', 'nerdcore', 'punk']
# 2  ['ambient techno', 'minimal techno', 'shoegaze...
# 3  ['alternative metal', 'heavy metal', 'progress...
# 4                                        ['hip hop']
#
#                                            image_url  rating
# 0  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...       7
# 1  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...       6
# 2  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...       7
# 3  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...       7
# 4  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...       7
