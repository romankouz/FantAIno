# %% [markdown]
# ## Imports

# %%
from dotenv import load_dotenv
load_dotenv()
import json
import jsonlines
import logging
import os
import pandas as pd

from lyricsgenius import Genius

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(levelname)s %(name)s: %(message)s",
)

logging.getLogger("lyricsgenius").setLevel(logging.INFO)

# %%
package_root_dir = os.path.join(os.getcwd(), "..")

# %% [markdown]
# ## Credentials

# %%
GENIUS_TOKEN = os.getenv("GENIUS_CLIENT_ACCESS_TOKEN")

# %% [markdown]
# ## Extract Melondy Data

# %%
FantAIno_df = pd.read_csv(os.path.join(package_root_dir, "data", "processed", "melondy_and_spotify.csv"))
FantAIno_df.head()
# Out:
#             artist                                     album  \
# 0        Integrity  Howling, for the Nightmare Shall Consume
# 1          Big Ups                        Two Parts Together
# 2        The Field                     Looping State of Mind
# 3         Mastodon                   Once More Round the Sun
# 4  Various Artists                         Dorner vs. Tookie
#
#                                            image_url  rating  is_garage rock  \
# 0  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...     7.0            True
# 1  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...     6.0           False
# 2  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...     7.0           False
# 3  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...     7.0           False
# 4  https://d1j3ls2jacen4o.cloudfront.net/thumbnai...     7.0           False
#
#    is_hardcore punk  is_punk  is_rock  is_pop  is_art rock  ...  \
# 0              True     True     True   False        False  ...
# 1             False    False    False    True        False  ...
# 2             False    False     True   False         True  ...
# 3             False    False     True    True         True  ...
# 4             False    False    False   False        False  ...
#
#    num_available_markets  release_year  release_month  release_day  \
# 0                  185.0        2017.0            7.0         14.0
# 1                  185.0        2018.0            5.0         18.0
# 2                  185.0        2011.0            9.0          5.0
# 3                  170.0        2014.0            6.0         20.0
# 4                    NaN           NaN            NaN          NaN
#
#    album_duration_in_s  explicit_proportion  featured_artists  num_features  \
# 0             3457.360             0.000000     ['Integrity']           1.0
# 1             1820.684             0.000000       ['Big Ups']           1.0
# 2             3841.086             0.000000     ['The Field']           1.0
# 3             3252.343             0.181818      ['Mastodon']           1.0
# 4                  NaN                  NaN               NaN           NaN
#
#                                          track_names  artist_popularity
# 0  ['Fallen to Destroy', 'Blood Sermon', 'Hymn fo...               34.0
# 1  ['Two Parts Together', 'In the Shade', 'Trying...                0.0
# 2  ['Is This Power', 'It´s Up There', 'Burned Out...               34.0
# 3  ['Tread Lightly', 'The Motherload', 'High Road...               63.0
# 4                                                NaN                NaN
#
# [5 rows x 89 columns]

# %%
FantAIno_df.shape
# Out:
# (3293, 89)

# %%
FantAIno_df.columns
# Out:
# Index(['artist', 'album', 'image_url', 'rating', 'is_garage rock',
#        'is_hardcore punk', 'is_punk', 'is_rock', 'is_pop', 'is_art rock',
#        'is_alternative rock', 'is_art pop', 'is_chamber pop', 'is_indie folk',
#        'is_indie rock', 'is_singer-songwriter', 'is_hip hop', 'is_dance-pop',
#        'is_electropop', 'is_pop rap', 'is_alternative hip hop', 'is_downtempo',
#        'is_electronic', 'is_pop rock', 'is_black metal', 'is_folk',
#        'is_No genres', 'is_experimental hip hop', 'is_hardcore hip hop',
#        'is_neo-psychedelia', 'is_synth-pop', 'is_alternative pop',
#        'is_conscious hip hop', 'is_experimental', 'is_folk rock',
#        'is_leftfield', 'is_ambient', 'is_noise', 'is_east coast hip hop',
#        'is_doom metal', 'is_psychedelic rock', 'is_experimental rock',
#        'is_post-rock', 'is_contemporary r&b', 'is_trap', 'is_new wave',
#        'is_metal', 'is_indie pop', 'is_alternative r&b', 'is_jazz',
#        'is_avant-garde', 'is_death metal', 'is_neo soul', 'is_soul',
#        'is_psychedelic', 'is_house', 'is_alternative metal', 'is_lo-fi',
#        'is_post-punk', 'is_heavy metal', 'is_progressive metal',
#        'is_industrial', 'is_noise rock', 'is_idm', 'is_hard rock',
#        'is_post-hardcore', 'is_funk', 'is_indietronica', 'is_electro',
#        'is_r&b', 'is_southern hip hop', 'is_dream pop', 'is_shoegaze',
#        'is_gangsta rap', 'is_alternative dance', 'is_punk rock', 'is_pop punk',
#        'is_emo', 'total_tracks', 'num_available_markets', 'release_year',
#        'release_month', 'release_day', 'album_duration_in_s',
#        'explicit_proportion', 'featured_artists', 'num_features',
#        'track_names', 'artist_popularity'],
#       dtype='object')

# %% [markdown]
# # Genius API Demo

# %%
genius = Genius(GENIUS_TOKEN)

# %% [markdown]
# ### Search Artist

# %%
artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
print(artist.songs)
# Out:
# [Song(title=Alexander All Alone, artist=Andy Shauf), Song(title=All Of My Love, artist=Andy Shauf), Song(title=All the Same, artist=Andy Shauf)]

# %% [markdown]
# **Note**: If you try to remove the max_songs argument, it will pull ALL the songs, which can take a while. It is best to use this API with a specific album/song in mind.

# %%
album = genius.search_album("Recovery", artist="Eminem")
print(album)

# %%
dir(album)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_body',
#  '_text_data',
#  'api_path',
#  'artist',
#  'cover_art_thumbnail_url',
#  'cover_art_url',
#  'full_title',
#  'name',
#  'name_with_artist',
#  'release_date_components',
#  'save_lyrics',
#  'to_dict',
#  'to_json',
#  'to_text',
#  'tracks',
#  'url']

# %%
album.to_dict()["tracks"]
# Out:
# [{'number': 1,
#   'song': {'_type': 'song',
#    'annotation_count': 38,
#    'api_path': '/songs/533',
#    'artist_names': 'Eminem',
#    'full_title': 'Cold Wind Blows by\xa0Eminem',
#    'header_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'id': 533,
#    'instrumental': False,
#    'lyrics_owner_id': 17,
#    'lyrics_state': 'complete',
#    'lyrics_updated_at': 1773275369,
#    'path': '/Eminem-cold-wind-blows-lyrics',
#    'primary_artist_names': 'Eminem',
#    'pyongs_count': 118,
#    'relationships_index_url': 'https://genius.com/Eminem-cold-wind-blows-sample',
#    'release_date_components': {'year': 2010, 'month': 6, 'day': 18},
#    'release_date_for_display': 'June 18, 2010',
#    'release_date_with_abbreviated_month_for_display': 'Jun. 18, 2010',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 9, 'hot': False, 'pageviews': 611207},
#    'title': 'Cold Wind Blows',
#    'title_with_featured': 'Cold Wind Blows',
#    'updated_by_human_at': 1773275369,
#    'url': 'https://genius.com/Eminem-cold-wind-blows-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'_type': 'artist',
#     'api_path': '/artists/45',
#     'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#     'id': 45,
#     'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#     'index_character': 'e',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'links_config': None,
#     'name': 'Eminem',
#     'slug': 'Eminem',
#     'url': 'https://genius.com/artists/Eminem',
#     'iq': 294903},
#    'primary_artists': [{'_type': 'artist',
#      'api_path': '/artists/45',
#      'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#      'id': 45,
#      'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#      'index_character': 'e',
#      'is_meme_verified': True,
#      'is_verified': True,
#      'links_config': None,
#      'name': 'Eminem',
#      'slug': 'Eminem',
#      'url': 'https://genius.com/artists/Eminem',
#      'iq': 294903}],
#    'artist': 'Eminem',
#    'lyrics': '[
psycho, yeah\nPlus you got to rewrite those lines that you said about Michael\'s hair (Whoops)\n\n[Chorus]\n(You\'re on fire) That\'s how you know you\'re on a roll\n\'Cause when you\'re hot, it\'s like you\'re burnin\' up everyone else\'s cold\n(You\'re on fire) Man, I\'m so—, I\'m so hot\nMy motherfuckin\' firetruck\'s on fire, homie\n(You\'re on fire) You need to stop, drop, and roll\n\'Cause when you say the shit to get the whole hip-hop shop to blow\n(You\'re on fire) yea ...
#  {'number': 4,
#   'song': {'_type': 'song',
#    'annotation_count': 37,
#    'api_path': '/songs/520',
#    'artist_names': 'Eminem & P!nk',
#    'full_title': "Won't Back Down by\xa0Eminem & P!nk",
#    'header_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'id': 520,
#    'instrumental': False,
#    'lyrics_owner_id': 17,
#    'lyrics_state': 'complete',
#    'lyrics_updated_at': 1752718442,
#    'path': '/Eminem-and-p-nk-wont-back-down-lyrics',
#    'primary_artist_names': 'Eminem & P!nk',
#    'pyongs_count': 62,
#    'relationships_index_url': 'https://genius.com/Eminem-and-p-nk-wont-back-down-sample',
#    'release_date_components': {'year': 2010, 'month': 6, 'day': 18},
#    'release_date_for_display': 'June 18, 2010',
#    'release_date_with_abbreviated_month_for_display': 'Jun. 18, 2010',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 409921},
#    'title': 'Won’t Back Down',
#    'title_with_featured': "Won't Back Down",
#    'updated_by_human_at': 1768454518,
#    'url': 'https://genius.com/Eminem-and-p-nk-wont-back-down-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'_type': 'artist',
#     'api_path': '/artists/45',
#     'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#     'id': 45,
#     'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#     'index_character': 'e',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'links_config': None,
#     'name': 'Eminem',
#     'slug': 'Eminem',
#     'url': 'https://genius.com/artists/Eminem',
#     'iq': 294903},
#    'primary_artists': [{'_type': 'artist',
#      'api_path': '/artists/45',
#      'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#      'id': 45,
#      'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#      'index_character': 'e',
#      'is_meme_verified': True,
#      'is_verified': True,
#      'links_config': None,
#      'name': 'Eminem',
#      'slug': 'Eminem',
#      'url': 'https://genius.com/artists/Eminem',
#      'iq': 294903},
#     {'_type': 'artist',
#      'api_path': '/artists/345',
#      'header_image_url': 'https://images.genius.com/11facbd75b31914d4fce4d11a67612ed.1000x333x1.jpg',
#      'id': 345,
#      'image_url': 'https://images.genius.com/8e9d7b2c7e977c8009872f1b28d369c0.474x474x1.jpg',
#      'index_character': 'p',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'links_config': None,
#      'name': 'P!nk',
#      'slug': 'P-nk',
#      'url': 'https://genius.com/artists/P-nk'}],
#    'artist': 'Eminem',
#    'lyrics': '[Chorus: P!nk]\nYou can sound the alarm, you can call out your guards\nYou can fence in your yard, you can hold all the cards\nBut I won\'t back down\nOh no, I won\'t back down, oh no\n\n[Verse 1: Eminem]\nCadillac Sevilles, coupe DeVilles\nBrain-dead rims, yeah, stupid wheels\nGirl, I\'m too for real, lose your tooth-and-nail\nTryna fight it, try to deny it, stupid, you will feel\nWhat I do, I do it well\nShootin\' from the hip, yeah, boy, I shoot to kill\nHalf a breath left on my deathbed\nScreamin\', "F that",  yeah, super-ill\nBaby, what the deal? We can chill\nSplit a half a pill and a Happy Meal\nFuck a steak, slut, I\'ll cut my toes off\nAnd step on the receipt \'fore I foot the bill\nListen, garden tool, don\'t make me introduce you\nTo my power tool, you know the fuckin\' drill\nHow you douchebags feel knowin\' you\'re disposable?\nSummer\'s Eve, Massengill\nShady\'s got the mass appeal\nBaby, crank the shit, \'cause it\'s your goddamn jam\nYou said that you want your punchlines a little more compact\nWell, shorty, I\'m that man\nThese other cats ain\'t metaphorically where I\'m at, man\nI gave Bruce Wayne a Valium\nAnd said, "Settle your fuckin\' ass down\nI\'m ready for combat, man"\nGet it? Calm Batman, nah\nAin\'t nobody who\'s as bomb and as\nNuts, lines are like Mom\'s CAT-scans\n\'Cause they fuckin\' go bananas\nHoney, I applaud that ass\nSwear to God, man, these broads can\'t dance\nMa, show \'em how it\'s done\nSp
chin\'\nThis game, pacin\' these hallways, you had faith in me always\nProof, you knew I\'d come out of this slump, rise from these ashes\nCome right back on their asses and go Mike Tyson on these bastards\nAnd I\'ma show \'em, blow \'em out the water, slaughter \'em, homes\nI\'ma own so many belts, only place they can hit me is below \'em\nHomie, I know I\'m never gonna be the same without you\nI never woulda came in this game, I\'m goin\' insane without you\nMatter fact, it was just the other night, had another dream about you\nYou told me to get up, I got up, I spread my wings and I flew\nYou gave me a reason to fight, I was on my way to see you\nYou told me, "Naw, Doody, you\'re not!"; layin\' on that table, I knew\nI was gonna make it; soon as you said, "Think of Hailie" I knew\nThere wasn\'t no way that I was ever gonna leave them babies; and Proof\nNot many are lucky enough to have a gua ...
#  {'number': 17,
#   'song': {'_type': 'song',
#    'annotation_count': 37,
#    'api_path': '/songs/575',
#    'artist_names': 'Eminem',
#    'full_title': 'Untitled by\xa0Eminem',
#    'header_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'id': 575,
#    'instrumental': False,
#    'lyrics_owner_id': 7,
#    'lyrics_state': 'complete',
#    'lyrics_updated_at': 1767852960,
#    'path': '/Eminem-untitled-lyrics',
#    'primary_artist_names': 'Eminem',
#    'pyongs_count': 56,
#    'relationships_index_url': 'https://genius.com/Eminem-untitled-sample',
#    'release_date_components': {'year': 2010, 'month': 6, 'day': 18},
#    'release_date_for_display': 'June 18, 2010',
#    'release_date_with_abbreviated_month_for_display': 'Jun. 18, 2010',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/741f6a6c46763fceb09ea5d70d41daf3.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 289090},
#    'title': 'Untitled',
#    'title_with_featured': 'Untitled',
#    'updated_by_human_at': 1774851498,
#    'url': 'https://genius.com/Eminem-untitled-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'_type': 'artist',
#     'api_path': '/artists/45',
#     'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#     'id': 45,
#     'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#     'index_character': 'e',
#     'is_meme_verified': True,
#     'is_verified': True,
#     'links_config': None,
#     'name': 'Eminem',
#     'slug': 'Eminem',
#     'url': 'https://genius.com/artists/Eminem',
#     'iq': 294903},
#    'primary_artists': [{'_type': 'artist',
#      'api_path': '/artists/45',
#      'header_image_url': 'https://images.genius.com/7879bf220b8614a7fe4617006f132a92.1000x391x1.png',
#      'id': 45,
#      'image_url': 'https://images.genius.com/c83ceb16a658c04f606d6e4b55a9b0cc.921x921x1.jpg',
#      'index_character': 'e',
#      'is_meme_verified': True,
#      'is_verified': True,
#      'links_config': None,
#      'name': 'Eminem',
#      'slug': 'Eminem',
#      'url': 'https://genius.com/artists/Eminem',
#      'iq': 294903}],
#    'artist': 'Eminem',
#    'lyrics': '[Intro: Eminem & Lesley Gore]\nYou don\'t own me\nNah, man—not quite finished yet\nI\'m not just one of your many toys\nHa-ha, woo\n\n[Verse 1: Eminem & Lesley Gore]\nGirl, I think you just might\'ve tried to pull a motherfuckin\' fast one, I\'m mad\nYou just hurt my goddamn feeling and that was the last one I had\nDoes this look like an arcade? Tryna play games? See this saw blade?\nSee this silhouette of a stalker in your walk

#  '__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__parameters__',
#  '__protocol_attrs__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_get_item_from_search_response',
#  '_is_protocol',
#  '_is_runtime_protocol',
#  '_make_request',
#  '_result_is_lyrics',
#  '_result_is_match',
#  '_session',
#  'access_token',
#  'account',
#  'album',
#  'album_comments',
#  'album_cover_arts',
#  'album_leaderboard',
#  'album_tracks',
#  'albums_charts',
#  'annotation',
#  'annotation_comments',
#  'annotation_edits',
#  'article',
#  'article_comments',
#  'artist',
#  'artist_activity',
#  'artist_albums',
#  'artist_contribution_opportunities',
#  'artist_followers',
#  'artist_leaderboard',
#  'artist_songs',
#  'authorization_header',
#  'charts',
#  'cover_arts',
#  'create_annotation',
#  'default_terms',
#  'delete_annotation',
#  'discussion',
#  'discussion_replies',
#  'discussions',
#  'downvote_annotation',
#  'excluded_terms',
#  'latest_articles',
#  'leaderboard',
#  'line_item',
#  'lyrics',
#  'page_data',
#  'per_page',
#  'questions',
#  'referent',
#  'referents',
#  'referents_charts',
#  'remove_section_headers',
#  'response_format',
#  'retries',
#  'search',
#  'search_album',
#  'search_albums',
#  'search_all',
#  'search_articles',
#  'search_artist',
#  'search_artist_songs',
#  'search_artists',
#  'search_lyrics',
#  'search_song',
#  'search_songs',
#  'search_users',
#  'search_videos',
#  'skip_non_songs',
#  'sleep_time',
#  'song',
#  'song_activity',
#  'song_annotations',
#  'song_comments',
#  'song_contributors',
#  'tag',
#  'timeout',
#  'unvote_annotation',
#  'update_annotation',
#  'upvote_annotation',
#  'user',
#  'user_accomplishments',
#  'user_annotations',
#  'user_articles',
#  'user_contributions',
#  'user_followers',
#  'user_following',
#  'user_pyongs',
#  'user_questions_and_answers',
#  'user_suggestions',
#  'user_transcriptions',
#  'user_unreviewed',
#  'video',
#  'videos',
#  'voters',
#  'web_page']

# %% [markdown]
# # Save Lyrics to JSONLines

# %%
logger = logging.getLogger(__name__)
logging.basicConfig(filename='extract_lyrics.log', encoding='utf-8', level=logging.DEBUG)

if not os.path.isfile("lyrics.jsonl"):
    with open("lyrics.jsonl", "w", encoding="utf-8") as f:
        pass  # create empty file

# don't use API credits on processed albums
cached_lyrics = set()
with open('lyrics.jsonl', mode='r', encoding='utf-8') as cached_lyrics_reader:
    for line in cached_lyrics_reader:
        if json.loads(line) == []:
            break
        else:
            cached_album = json.loads(line)
            cached_lyrics.add((cached_album['artist'], cached_album['album']))

for index, FantAIno_entry in FantAIno_df.iterrows():

    # don't use API credits on processed albums
    if (FantAIno_entry['artist'], FantAIno_entry['album']) in cached_lyrics:
        logger.info(f"Skipping {FantAIno_entry['artist']} - {FantAIno_entry['album']} is already cached.")
        continue

    else:

        # get album
        try:
            album = genius.search_album(
                name=FantAIno_entry['album'],
                artist=FantAIno_entry['artist']
            )
            if album is None:
                logger.warning(f"Album '{FantAIno_entry['album']}' by '{FantAIno_entry['artist']}' not found")
                continue
        except Exception as e:
            logger.error(f"Error finding album {FantAIno_entry['album']}: {repr(e)}.")
            continue
        
        # save lyrics
        album_obj = {
            "artist": FantAIno_entry["artist"],
            "album": FantAIno_entry["album"],
            "tracks": {}
        }
        for track in album.to_dict()["tracks"]:
            album_obj["tracks"][track["song"]["title"]] = track["song"]["lyrics"]
        with jsonlines.open('lyrics.jsonl', mode='a') as writer:
            writer.write(album_obj)
                
    logger.info(f"Finished processing artist & album: {FantAIno_entry['artist']}, {FantAIno_entry['album']}")
# Out:
# INFO __main__: Finished processing artist & album: OFF!, First Four EPs
# INFO lyricsgenius.genius: Searching for "Rooms of the House" by La Dispute...
# INFO __main__: Finished processing artist & album: La Dispute, Rooms of the House
# INFO lyricsgenius.genius: Searching for "Shadow of a Doubt" by Freddie Gibbs...
# INFO __main__: Finished processing artist & album: Freddie Gibbs, Shadow of a Doubt
# INFO lyricsgenius.genius: Searching for "SWAG" by Justin Bieber...
# INFO __main__: Finished processing artist & album: Justin Bieber, SWAG
# INFO lyricsgenius.genius: Searching for "Duality" by Captain Murphy...
# INFO __main__: Finished processing artist & album: Captain Murphy, Duality
# INFO lyricsgenius.genius: Searching for "Paradise" by Pop. 1280...
# INFO __main__: Finished processing artist & album: Pop. 1280, Paradise
# INFO lyricsgenius.genius: Searching for "Attempted Martyr" by Prostitute...
# INFO __main__: Finished processing artist & album: Prostitute, Attempted Martyr
# INFO lyricsgenius.genius: Searching for "St. Vincent" by St. Vincent...
# INFO __main__: Finished processing artist & album: St. Vincent, St. Vincent
# INFO lyricsgenius.genius: Searching for "Bitches Brew" by Miles Davis...
# INFO __main__: Finished processing artist & album: Miles Davis, Bitches Brew
# INFO lyricsgenius.genius: Searching for "Stand For Myself" by Yola...
# INFO __main__: Finished processing artist & album: Yola, Stand For Myself
# INFO lyricsgenius.genius: Searching for "Seeds" by TV on the Radio...
# INFO __main__: Finished processing artist & album: TV on the Radio, Seeds
# INFO lyricsgenius.genius: Searching for "The Parallax II: Future Sequence" by Between the Buried and Me...
# INFO __main__: Finished processing artist & album: Between the Buried and Me, The Parallax II: Future Sequence
# INFO lyricsgenius.genius: Searching for "Aethiopes" by billy woods...
# INFO __main__: Finished processing artist & album: billy woods, Aethiopes
# INFO lyricsgenius.genius: Searching for "TESTING" by A$AP Rocky...
# INFO __main__: Finished processing artist & album: A$AP Rocky, TESTING
# INFO lyricsgenius.genius: Searching for "Man on the Moon III: The Chosen" by Kid Cudi...
# INFO __main__: Finished processing artist & album: Kid Cudi, Man on the Moon III: The Chosen
# INFO lyricsgenius.genius: Searching for "Known Unknowns" by billy woods...
# INFO __main__: Finished processing artist & album: billy woods, Known Unknowns
# INFO lyricsgenius.genius: Searching for "AMERICAN GURL" by Kilo Kish...
# INFO __main__: Finished processing artist & album: Kilo Kish, AMERICAN GURL
# INFO lyricsgenius.genius: Searching for "BLACK STAR" by Amaarae...
TPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)").
# INFO lyricsgenius.genius: Searching for "Kauai" by Childish Gambino...
# INFO __main__: Finished processing artist & album: Childish Gambino, Kauai
# INFO lyricsgenius.genius: Searching for "New Chain" by Small Black...
# INFO __main__: Finished processing artist & album: Small Black, New Chain
# INFO lyricsgenius.genius: Searching for "No Closer to Heaven" by The Wonder Years...
# INFO __main__: Finished processing artist & album: The Wonder Years, No Closer to Heaven
# INFO lyricsgenius.genius: Searching for "Tripper" by Hella...
# INFO __main__: Finished processing artist & album: Hella, Tripper
# INFO lyricsgenius.genius: Searching for "Balkans" by Balkans...
# INFO __main__: Finished processing artist & album: Balkans, Balkans
# INFO lyricsgenius.genius: Searching for "Steel Mogu" by Iglooghost...
# INFO __main__: Finished processing artist & album: Iglooghost, Steel Mogu
# INFO lyricsgenius.genius: Searching for "What a Time to Be Alive" by Drake & Future...
# INFO __main__: Finished processing artist & album: Drake & Future, What a Time to Be Alive
# INFO lyricsgenius.genius: Searching for "Live From The Dentist Office" by Injury Reserve...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 28
#      24 else:
#      25
#      26     # get album
#      27     try:
# ---> 28         album = genius.search_album(
#      29             name=FantAIno_entry['album'],
#      30             artist=FantAIno_entry['artist']
#      31         )
#      32         if album is None:
#      33             logger.info(f"Album '{FantAIno_entry['album']}' by '{FantAIno_entry['artist']}' not found")
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\lyricsgenius\genius.py:461, in Genius.search_album(self, name, artist, album_id, get_full_info, text_format, fetch_lyrics)
#     455 song_lyrics = None
#     456 if (
#     457     fetch_lyrics
#     458     and song_info["lyrics_state"] == "complete"
#     459     and not song_info.get("instrumental")
#     460 ):
# --> 461     song_lyrics = self.lyrics(song_url=song_info["url"])
#     463 if song_lyrics is None:
#     464     song_lyrics = ""
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\lyricsgenius\genius.py:192, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     189     raise ValueError("You must supply either `song_id` or `song_url`.")
#     191 # Scrape the song lyrics from the HTML
# --> 192 soup = BeautifulSoup(self._make_request(path, web=True)["html"], "html.parser")
#     194 # Remove LyricsHeader divs from the DOM
#     195 removes = soup.find_all("div", class_=re.compile("LyricsHeader"))
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\lyricsgenius\api\base.py:88, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      86 tries += 1
#      87 try:
# ---> 88     response = self._session.request(
#      89         method,
#      90         uri,
#      91         timeout=self.timeout,
#      92         params=params_,
#      93         headers=header,
#      94         **kwargs,
#      95     )
#      96 except Timeout as e:
#      97     error = f"Request timed out:\n{e}"
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\requests\sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587 send_kwargs = {
#     588     "timeout": timeout,
#     589     "allow_redirects": allow_redirects,
#     590 }
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\requests\sessions.py:706, in Session.send(self, request, **kwargs)
#     703 start = preferred_clock()
#     705 # Send the request
# --> 706 r = adapter.send(request, **kwargs)
#     708 # Total elapsed time of the request (approximately)
#     709 elapsed = preferred_clock() - start
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\requests\adapters.py:645, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     642     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     644 try:
# --> 645     resp = conn.urlopen(
#     646         method=request.method,
#     647         url=url,
#     648         body=request.body,
#     649         headers=request.headers,
#     650         redirect=False,
#     651         assert_same_host=False,
#     652         preload_content=False,
#     653         decode_content=False,
#     654         retries=self.max_retries,
#     655         timeout=timeout,
#     656         chunked=chunked,
#     657     )
#     659 except (ProtocolError, OSError) as err:
#     660     raise ConnectionError(err, request=request)
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Owner\Documents\SillyProjects\FantAIno\FantAIno\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
